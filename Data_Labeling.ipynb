# %%
import numpy as np
import pandas as pd
import os
import re
import shutil

# %%
#Labels for train and test data for both calc and mass cases

## Train data labels
calc_train = pd.read_csv("calc_case_description_train_set.csv")
calc_train['image_name'] = calc_all_train.patient_id + '_' + calc_all_train['left or right breast'] + '_' + calc_all_train['image view'] + '.png'
calc_train.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
calc_train.columns = ["Patient_ID","Breast_Density","Side_L_R","Image View","Abnormality_ID","Abnormality_Type","Mass_Shape","Mass_Margins","Assessment","Pathology", "Subtlety","Image_Name"]

mass_train = pd.read_csv("mass_case_description_train_set.csv")
mass_train['image_name'] = mass_all_train.patient_id + '_' + mass_all_train['left or right breast'] + '_' + mass_all_train['image view'] + '.png'
mass_train.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
mass_train.columns = ["Patient_ID","Breast_Density","Side_L_R","Image View","Abnormality_ID","Abnormality_Type","Mass_Shape","Mass_Margins","Assessment","Pathology", "Subtlety","Image_Name"]


## Test data labels
calc_test = pd.read_csv("calc_case_description_test_set.csv")
calc_test['image_name'] = calc_all_test.patient_id + '_' + calc_all_test['left or right breast'] + '_' + calc_all_test['image view'] + '.png'
calc_test.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
calc_test.columns = ["Patient_ID","Breast_Density","Side_L_R","Image View","Abnormality_ID","Abnormality_Type","Mass_Shape","Mass_Margins","Assessment","Pathology", "Subtlety","Image_Name"]

mass_test = pd.read_csv("mass_case_description_test_set.csv")
mass_test['image_name'] = mass_all_test.patient_id + '_' + mass_all_test['left or right breast'] + '_' + mass_all_test['image view'] + '.png'
mass_test.drop(["image file path","cropped image file path","ROI mask file path"], axis=1, inplace=True)
mass_test.columns = ["Patient_ID","Breast_Density","Side_L_R","Image View","Abnormality_ID","Abnormality_Type","Mass_Shape","Mass_Margins","Assessment","Pathology", "Subtlety","Image_Name"]


# Train and Test label
train_label = pd.concat([calc_all_train, mass_all_train], axis = 0)
train_label['Pathology'][train_label['Pathology'] == 'BENIGN_WITHOUT_CALLBACK'] = 'BENIGN'
train_label['Class'] = train_label['Pathology'] + '_' + train_label['Abnormality_Type']

test_label = pd.concat([calc_all_test, mass_all_test], axis = 0)
test_label['Pathology'][test_label['Pathology'] == 'BENIGN_WITHOUT_CALLBACK'] = 'BENIGN'
test_label['Class'] = test_label['Pathology'] + '_' + test_label['Abnormality_Type']

# Set image_name to be the index
train_label.set_index("Image_Name", inplace = True)
test_label.set_index("Image_Name", inplace = True)

#test_label.head()
# Out:
# C:\Users\kk64\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\kk64\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
calc_train.head()
# Out:
#   Patient_ID  Breast_Density Side_L_R Image View  Abnormality_ID  \
# 0    P_00005               3    RIGHT         CC               1
# 1    P_00005               3    RIGHT        MLO               1
# 2    P_00007               4     LEFT         CC               1
# 3    P_00007               4     LEFT        MLO               1
# 4    P_00008               1     LEFT         CC               1
#
#   Abnormality_Type   Mass_Shape Mass_Margins  Assessment  \
# 0    calcification    AMORPHOUS    CLUSTERED           3
# 1    calcification    AMORPHOUS    CLUSTERED           3
# 2    calcification  PLEOMORPHIC       LINEAR           4
# 3    calcification  PLEOMORPHIC       LINEAR           4
# 4    calcification          NaN     REGIONAL           2
#
#                  Pathology  Subtlety             Image_Name
# 0                MALIGNANT         3   P_00005_RIGHT_CC.png
# 1                MALIGNANT         3  P_00005_RIGHT_MLO.png
# 2                   BENIGN         4    P_00007_LEFT_CC.png
# 3                   BENIGN         4   P_00007_LEFT_MLO.png
# 4  BENIGN_WITHOUT_CALLBACK         3    P_00008_LEFT_CC.png

# %%
mass_train.head()
# Out:
#   Patient_ID  Breast_Density Side_L_R Image View  Abnormality_ID  \
# 0    P_00001               3     LEFT         CC               1
# 1    P_00001               3     LEFT        MLO               1
# 2    P_00004               3     LEFT         CC               1
# 3    P_00004               3     LEFT        MLO               1
# 4    P_00004               3    RIGHT        MLO               1
#
#   Abnormality_Type                          Mass_Shape   Mass_Margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 2             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 3             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 4             mass                                OVAL  CIRCUMSCRIBED
#
#    Assessment  Pathology  Subtlety             Image_Name
# 0           4  MALIGNANT         4    P_00001_LEFT_CC.png
# 1           4  MALIGNANT         4   P_00001_LEFT_MLO.png
# 2           4     BENIGN         3    P_00004_LEFT_CC.png
# 3           4     BENIGN         3   P_00004_LEFT_MLO.png
# 4           4     BENIGN         5  P_00004_RIGHT_MLO.png

# %%
calc_test.head()
# Out:
#   Patient_ID  Breast_Density Side_L_R Image View  Abnormality_ID  \
# 0    P_00038               2     LEFT         CC               1
# 1    P_00038               2     LEFT        MLO               1
# 2    P_00038               2    RIGHT         CC               1
# 3    P_00038               2    RIGHT         CC               2
# 4    P_00038               2    RIGHT        MLO               1
#
#   Abnormality_Type            Mass_Shape Mass_Margins  Assessment  \
# 0    calcification  PUNCTATE-PLEOMORPHIC    CLUSTERED           4
# 1    calcification  PUNCTATE-PLEOMORPHIC    CLUSTERED           4
# 2    calcification              VASCULAR          NaN           2
# 3    calcification              VASCULAR          NaN           2
# 4    calcification              VASCULAR          NaN           2
#
#                  Pathology  Subtlety             Image_Name
# 0                   BENIGN         2    P_00038_LEFT_CC.png
# 1                   BENIGN         2   P_00038_LEFT_MLO.png
# 2  BENIGN_WITHOUT_CALLBACK         5   P_00038_RIGHT_CC.png
# 3  BENIGN_WITHOUT_CALLBACK         5   P_00038_RIGHT_CC.png
# 4  BENIGN_WITHOUT_CALLBACK         5  P_00038_RIGHT_MLO.png

# %%
mass_test.head()
# Out:
#   Patient_ID  Breast_Density Side_L_R Image View  Abnormality_ID  \
# 0    P_00016               4     LEFT         CC               1
# 1    P_00016               4     LEFT        MLO               1
# 2    P_00017               2     LEFT         CC               1
# 3    P_00017               2     LEFT        MLO               1
# 4    P_00032               3    RIGHT         CC               1
#
#   Abnormality_Type Mass_Shape   Mass_Margins  Assessment  Pathology  Subtlety  \
# 0             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 1             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 2             mass      ROUND  CIRCUMSCRIBED           4  MALIGNANT         4
# 3             mass      ROUND    ILL_DEFINED           4  MALIGNANT         4
# 4             mass      ROUND       OBSCURED           0     BENIGN         2
#
#              Image_Name
# 0   P_00016_LEFT_CC.png
# 1  P_00016_LEFT_MLO.png
# 2   P_00017_LEFT_CC.png
# 3  P_00017_LEFT_MLO.png
# 4  P_00032_RIGHT_CC.png

# %%
train_label
# Out:
#                       Patient_ID  Breast_Density Side_L_R Image View  \
# Image_Name
# P_00005_RIGHT_CC.png     P_00005               3    RIGHT         CC
# P_00005_RIGHT_MLO.png    P_00005               3    RIGHT        MLO
# P_00007_LEFT_CC.png      P_00007               4     LEFT         CC
# P_00007_LEFT_MLO.png     P_00007               4     LEFT        MLO
# P_00008_LEFT_CC.png      P_00008               1     LEFT         CC
# ...                          ...             ...      ...        ...
# P_02033_RIGHT_MLO.png    P_02033               2    RIGHT        MLO
# P_02079_RIGHT_CC.png     P_02079               2    RIGHT         CC
# P_02079_RIGHT_MLO.png    P_02079               2    RIGHT        MLO
# P_02092_LEFT_CC.png      P_02092               2     LEFT         CC
# P_02092_LEFT_MLO.png     P_02092               2     LEFT        MLO
#
#                        Abnormality_ID Abnormality_Type   Mass_Shape  \
# Image_Name
# P_00005_RIGHT_CC.png                1    calcification    AMORPHOUS
# P_00005_RIGHT_MLO.png               1    calcification    AMORPHOUS
# P_00007_LEFT_CC.png                 1    calcification  PLEOMORPHIC
# P_00007_LEFT_MLO.png                1    calcification  PLEOMORPHIC
# P_00008_LEFT_CC.png                 1    calcification          NaN
# ...                               ...              ...          ...
# P_02033_RIGHT_MLO.png               1             mass    IRREGULAR
# P_02079_RIGHT_CC.png                1             mass        ROUND
# P_02079_RIGHT_MLO.png               1             mass        ROUND
# P_02092_LEFT_CC.png                 1             mass    IRREGULAR
# P_02092_LEFT_MLO.png                1             mass    IRREGULAR
#
#                       Mass_Margins  Assessment  Pathology  Subtlety  \
# Image_Name
# P_00005_RIGHT_CC.png     CLUSTERED           3  MALIGNANT         3
# P_00005_RIGHT_MLO.png    CLUSTERED           3  MALIGNANT         3
# P_00007_LEFT_CC.png         LINEAR           4     BENIGN         4
# P_00007_LEFT_MLO.png        LINEAR           4     BENIGN         4
# P_00008_LEFT_CC.png       REGIONAL           2     BENIGN         3
# ...                            ...         ...        ...       ...
# P_02033_RIGHT_MLO.png  ILL_DEFINED           3  MALIGNANT         4
# P_02079_RIGHT_CC.png    SPICULATED           3  MALIGNANT         5
# P_02079_RIGHT_MLO.png   SPICULATED           3  MALIGNANT         5
# P_02092_LEFT_CC.png     SPICULATED           3  MALIGNANT         2
# P_02092_LEFT_MLO.png    SPICULATED           3  MALIGNANT         2
#
#                                          Class
# Image_Name
# P_00005_RIGHT_CC.png   MALIGNANT_calcification
# P_00005_RIGHT_MLO.png  MALIGNANT_calcification
# P_00007_LEFT_CC.png       BENIGN_calcification
# P_00007_LEFT_MLO.png      BENIGN_calcification
# P_00008_LEFT_CC.png       BENIGN_calcification
# ...                                        ...
# P_02033_RIGHT_MLO.png           MALIGNANT_mass
# P_02079_RIGHT_CC.png            MALIGNANT_mass
# P_02079_RIGHT_MLO.png           MALIGNANT_mass
# P_02092_LEFT_CC.png             MALIGNANT_mass
# P_02092_LEFT_MLO.png            MALIGNANT_mass
#
# [2864 rows x 12 columns]

# %%
test_label
# Out:
#                       Patient_ID  Breast_Density Side_L_R Image View  \
# Image_Name
# P_00038_LEFT_CC.png      P_00038               2     LEFT         CC
# P_00038_LEFT_MLO.png     P_00038               2     LEFT        MLO
# P_00038_RIGHT_CC.png     P_00038               2    RIGHT         CC
# P_00038_RIGHT_CC.png     P_00038               2    RIGHT         CC
# P_00038_RIGHT_MLO.png    P_00038               2    RIGHT        MLO
# ...                          ...             ...      ...        ...
# P_01825_RIGHT_MLO.png    P_01825               2    RIGHT        MLO
# P_01833_RIGHT_MLO.png    P_01833               2    RIGHT        MLO
# P_01865_LEFT_MLO.png     P_01865               2     LEFT        MLO
# P_01912_RIGHT_CC.png     P_01912               3    RIGHT         CC
# P_01912_RIGHT_MLO.png    P_01912               3    RIGHT        MLO
#
#                        Abnormality_ID Abnormality_Type            Mass_Shape  \
# Image_Name
# P_00038_LEFT_CC.png                 1    calcification  PUNCTATE-PLEOMORPHIC
# P_00038_LEFT_MLO.png                1    calcification  PUNCTATE-PLEOMORPHIC
# P_00038_RIGHT_CC.png                1    calcification              VASCULAR
# P_00038_RIGHT_CC.png                2    calcification              VASCULAR
# P_00038_RIGHT_MLO.png               1    calcification              VASCULAR
# ...                               ...              ...                   ...
# P_01825_RIGHT_MLO.png               1             mass             LOBULATED
# P_01833_RIGHT_MLO.png               1             mass             IRREGULAR
# P_01865_LEFT_MLO.png                1             mass             IRREGULAR
# P_01912_RIGHT_CC.png                1             mass             IRREGULAR
# P_01912_RIGHT_MLO.png               1             mass             IRREGULAR
#
#                          Mass_Margins  Assessment  Pathology  Subtlety  \
# Image_Name
# P_00038_LEFT_CC.png         CLUSTERED           4     BENIGN         2
# P_00038_LEFT_MLO.png        CLUSTERED           4     BENIGN         2
# P_00038_RIGHT_CC.png              NaN           2     BENIGN         5
# P_00038_RIGHT_CC.png              NaN           2     BENIGN         5
# P_00038_RIGHT_MLO.png             NaN           2     BENIGN         5
# ...                               ...         ...        ...       ...
# P_01825_RIGHT_MLO.png  MICROLOBULATED           3     BENIGN         3
# P_01833_RIGHT_MLO.png     ILL_DEFINED           5  MALIGNANT         5
# P_01865_LEFT_MLO.png      ILL_DEFINED           4  MALIGNANT         2
# P_01912_RIGHT_CC.png       SPICULATED           5  MALIGNANT         4
# P_01912_RIGHT_MLO.png      SPICULATED           5  MALIGNANT         4
#
#                                       Class
# Image_Name
# P_00038_LEFT_CC.png    BENIGN_calcification
# P_00038_LEFT_MLO.png   BENIGN_calcification
# P_00038_RIGHT_CC.png   BENIGN_calcification
# P_00038_RIGHT_CC.png   BENIGN_calcification
# P_00038_RIGHT_MLO.png  BENIGN_calcification
# ...                                     ...
# P_01825_RIGHT_MLO.png           BENIGN_mass
# P_01833_RIGHT_MLO.png        MALIGNANT_mass
# P_01865_LEFT_MLO.png         MALIGNANT_mass
# P_01912_RIGHT_CC.png         MALIGNANT_mass
# P_01912_RIGHT_MLO.png        MALIGNANT_mass
#
# [704 rows x 12 columns]

# %%
#save labels
train_label.to_pickle("train_label.pkl")
test_label.to_pickle("test_label.pkl")
